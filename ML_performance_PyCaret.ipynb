# %%
import pandas as pd
data = pd.read_csv('datasets/final_elem+hard-feat_data.csv')

# %%
data
# Out:
#       Compound  ...  Formation_energy
# 0     OH-OH-Ba  ...         -1.865620
# 1     OH-OH-Be  ...         -1.597309
# 2     OH-OH-Ca  ...         -2.011544
# 3     OH-OH-Cd  ...         -1.114656
# 4     OH-OH-Co  ...         -0.993519
# ...        ...  ...               ...
# 3094  Se-Te-Sn  ...         -0.223685
# 3095  Se-Te-Tc  ...         -0.173823
# 3096  Se-Te-Ti  ...         -1.068113
# 3097   Se-Te-W  ...         -0.090886
# 3098  Se-Te-Zr  ...         -1.296801
#
# [3099 rows x 14 columns]

# %%
from pycaret.regression import *
clf = setup(data = data, target = 'Formation_energy', train_size=0.9)
# Out:
#                                Description             Value
# 0                               session_id              2448
# 1                                   Target  Formation_energy
# 2                            Original Data        (3099, 14)
# 3                           Missing Values             False
# 4                         Numeric Features                12
# 5                     Categorical Features                 1
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set      (2789, 2801)
# 10                    Transformed Test Set       (310, 2801)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
models = ['xgboost', 'catboost', 'lr', 'lasso', 'ridge', 'en', 'tr', 'kr', 'svm', 'knn', 'dt', 'rf', 'et', 'ada', 'gbr', 'mlp', 'lightgbm']
best = compare_models(sort='RMSE', include=models)
# Out:
#                                     Model     MAE     MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.1257  0.0302  0.1734  0.9517
# xgboost         Extreme Gradient Boosting  0.1319  0.0347  0.1857  0.9446
# catboost               CatBoost Regressor  0.1329  0.0349  0.1864  0.9442
# et                  Extra Trees Regressor  0.1406  0.0399  0.1993  0.9364
# rf                Random Forest Regressor  0.1450  0.0426  0.2058  0.9322
# gbr           Gradient Boosting Regressor  0.1647  0.0493  0.2218  0.9214
# dt                Decision Tree Regressor  0.1820  0.0700  0.2643  0.8889
# lr                      Linear Regression  0.2393  0.0977  0.3123  0.8450
# tr                     TheilSen Regressor  0.2401  0.0980  0.3127  0.8446
# ada                    AdaBoost Regressor  0.2534  0.0988  0.3142  0.8433
# mlp                         MLP Regressor  0.2650  0.1183  0.3436  0.8119
# ridge                    Ridge Regression  0.3030  0.1540  0.3922  0.7552
# ...

# %%
## The bar plot shown in Figure S3 can be easily plotted using above data
